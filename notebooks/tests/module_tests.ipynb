# %%
from utils.hadoop_setup import complete_hadoop_setup
# Out:
# ✔ HADOOP_HOME set to:, os.environ['HADOOP_HOME']
# ✔ Added to PATH: C:\hadoop\bin
#
#  ✔ winutils.exe: True
#  ✔ hadoop.dll: True
#
# 🎉 Setup complete!

# %%
complete_hadoop_setup()
# Out:
# ✔ HADOOP_HOME set to:, os.environ['HADOOP_HOME']
# ✔ Added to PATH: C:\hadoop\bin
#
#  ✔ winutils.exe: True
#  ✔ hadoop.dll: True
#
# 🎉 Setup complete!

# %%
from utils.hadoop_diagnostic import diagnose_hadoop_setup
# Out:
# ============================================================
# HADOOP SETUP DIAGNOSTICS
# ============================================================
#
# 1. HADOOP_HOME: C:\hadoop
#   - Directory exists: True
#   - Bin directory exists: True
#
# 2. Required Files:
#   - winutils.exe exists: True
#     Size: 112,640 bytes
#    - hadoop.dll exists: True
#   - Size: 85,504 bytes
#
# 3. System PATH includes Hadoop bin:
#   - Hadoop in PATH: False
#
# ============================================================
